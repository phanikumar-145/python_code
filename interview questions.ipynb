# %% [markdown]
# <a href="https://colab.research.google.com/github/phanikumar-145/python_code/blob/main/interview%20questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Problem:
# Given a list of integers nums and an integer target, return the indices of the two numbers such that they add up to the target.
# Example:
# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
# Explanation:
# 2 + 7 = 9

# %%
nums = [2,7,11,15]
target = 9
for i in range(len(nums)):
  for j in range(i+1,len(nums)):
    if nums[i]+nums[j] == 9:
      print([i,j])
# Out:
# [0, 1]

# %%
# Problem:
# Given a string s, find the first non-repeating character and return its index. If it doesn't exist, return -1.
# Example 1:
# Input: s = "leetcode"
# Output: 0
# Example 2:
# Input: s = "aabb"
# Output: -1
# 🔹 Requirements:

# %%
  s = "deepcode"
  for i in range(len(s)):
    if(s.count(s[i]))>1:
      pass
    else:
      print(i)
      break
  else:
    print("-1")
# Out:
# 3
